# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
def open_ac():
    #file_name = "/Users/steve/Documents/DSI-US-4/Projects/project-5/baseball_oracle/2018_Official_Baseball_Rules/baseball_rules.txt"
    file_name = "baseball wikipedia.txt"
    lines = pd.read_csv(file_name,sep='/n'
                    ,engine='python'
                   )
    lines = lines[lines['Rule_Text'].str.len() > 30]
    #lines = pd.DataFrame(lines['Rule_Text'].str.split(':',1).tolist(), #columns = ['comedian','statement'])
    #lines['response'] = lines['statement'].shift(-1)
    lines['response'] = lines['Rule_Text']
    return lines

# %%
# !ls
# Out:
# Dockerfile
# Wikipedia.ipynb
# __pycache__
# baseball wikipedia.rtf.sb-5ce48749-5WMiwL
# baseball wikipedia.txt
# baseball_oracle.py
# baseball_rules.txt
# baseball_wikipedia_parsed.txt
# chatbot_responder.py
# discover.py
# mtg.py
# objects
# requirements.txt
# run.py
# run_backup.py
# slackbot.py
# train_model.py
# who2.py
# who_is.py
# who_is_on_first_raw.txt
# whos_on_first_responder.py
# whos_on_first_responder_good.py
# whose_spyder.py

# %%
def open_and_sent_tokenize():
    file_name = "baseball_rules.txt"
    f = open(file_name
            )
    file_text= f.read()
    return file_text

# %%
corpus = open_and_sent_tokenize()

corpus = 'This is the first sentance. The next sentences looks like this. The third sentence.'

sentences = nltk.sent_tokenize(corpus)

# %%
texts = open_and_sent_tokenize()

sentences = nltk.sent_tokenize(texts)

sentences
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-56-04622ca581b6> in <module>()
# ----> 1 texts = open_and_sent_tokenize()
#       2
#       3 sentences = nltk.sent_tokenize(texts)
#       4
#       5 sentences
#
# <ipython-input-55-a4469092b294> in open_and_sent_tokenize()
#       3     f = open(file_name
#       4             )
# ----> 5     file_text= f.read()
#       6     return file_text
#
# /anaconda3/envs/dsi/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# ...

# %%
with open('baseball_rules_parsed.txt', mode='wt', encoding='utf-8') as myfile:
    myfile.write('\n'.join(sentences))

# %%
# !ls
# Out:
# Dockerfile
# Wikipedia.ipynb
# __pycache__
# baseball wikipedia.rtf.sb-5ce48749-5WMiwL
# baseball wikipedia.txt
# baseball_oracle.py
# baseball_rules.txt
# baseball_wikipedia_parsed.txt
# chatbot_responder.py
# discover.py
# mtg.py
# objects
# requirements.txt
# run.py
# run_backup.py
# slackbot.py
# train_model.py
# who2.py
# who_is.py
# who_is_on_first_raw.txt
# whos_on_first_responder.py
# whos_on_first_responder_good.py
# whose_spyder.py

# %%
texts = open_and_sent_tokenize()


#texts = 'this is the first sentance. The next sentences looks like this. The third sentence.'

for text in texts:
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        print(sentence)
        if len(sentence) > 25:
            words = nltk.word_tokenize(sentence)
            tagged_words = nltk.pos_tag(words)
            ne_tagged_words = nltk.ne_chunk(tagged_words)
            #print(ne_tagged_words)
            print(sentence)
# Out:
# R
# u
# l
# e
# _
# T
# e
# x
# t
# B
# a
# s
# e
# b
# a
# l
# l
# i
# s
# a
# b
# a
# t
# -
# a
# n
# d
# -
# b
# a
# l
# l
# g
# a
# m
# e
# p
# l
# a
# y
# e
# d
# b
# e
# t
# w
# e
# e
# n
# t
# w
# o
# o
# p
# p
# o
# s
# i
# n
# g
# t
# e
# a
# m
# s
# w
# h
# o
# t
# a
# k
# e
# t
# u
# r
# n
# s
# b
# a
# t
# t
# i
# n
# g
# a
# n
# d
# f
# i
# e
# l
# d
# i
# n
# g
# .
# T
# h
# e
# g
# a
# m
# e
# p
# r
# o
# c
# e
# e
# d
# s
# w
# h
# e
# n
# a
# p
# l
# a
# y
# e
# r
# o
# n
# t
# h
# e
# f
# i
# e
# l
# d
# i
# n
# g
# t
# e
# a
# m
# ,
# c
# a
# l
# l
# e
# d
# t
# h
# e
# p
# i
# t
# c
# h
# e
# r
# ,
# t
# h
# r
# o
# w
# s
# a
# b
# a
# l
# l
# w
# h
# i
# c
# h
# a
# p
# l
# a
# y
# e
# r
# o
# n
# t
# h
# e
# b
# a
# t
# t
# i
# n
# g
# t
# e
# a
# m
# t
# r
# i
# e
# s
# t
# o
# h
# i
# t
# w
# i
# t
# h
# a
# b
# a
# t
# .
# T
# h
# e
# o
# b
# j
# e
# c
# t
# i
# v
# e
# s
# o
# f
# t
# h
# e
# o
# f
# f
# e
# n
# s
# i
# v
# e
# t
# e
# a
# m
# (
# b
# a
# t
# ...

# %%
# Out:
# ['.']
